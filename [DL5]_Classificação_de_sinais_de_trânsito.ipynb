# %% [markdown]
# <a href="https://colab.research.google.com/github/tvaditya/intro_ds_and_ml/blob/main/%5BDL5%5D_Classifica%C3%A7%C3%A3o_de_sinais_de_tr%C3%A2nsito.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto 8: Classificação de sinais de trânsito

# %% [markdown]
# Arquitetura LeNet: http://yann.lecun.com/exdb/publis/pdf/lecun-01a.pdf

# %% [markdown]
# # Etapa 1: Importação das bibliotecas

# %%
# %tensorflow_version 2.x
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import tensorflow as tf
import pandas as pd
import seaborn as sns
import pickle
import zipfile
tf.__version__
# Out:
# TensorFlow 2.x selected.
# '2.1.0-rc1'

# %% [markdown]
# # Etapa 2: Importação da base de dados

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/traffic-signs-data.zip'
zip_object = zipfile.ZipFile(file=path, mode='r')
zip_object.extractall('./')
zip_object.close()

# %%
with open('/content/traffic-signs-data/train.p', mode='rb') as training_data:
  train = pickle.load(training_data)
with open('/content/traffic-signs-data/test.p', mode='rb') as testing_data:
  test = pickle.load(testing_data)
with open('/content/traffic-signs-data/valid.p', mode='rb') as validation_data:
  valid = pickle.load(validation_data)

# %%
train
# Out:
# {'coords': array([[  6,   5,  21,  20],
#         [  6,   6,  22,  22],
#         [  5,   6,  22,  23],
#         ...,
#         [ 17,  15, 178, 155],
#         [ 17,  15, 183, 160],
#         [ 20,  18, 211, 184]], dtype=uint8),
#  'features': array([[[[ 28,  25,  24],
#           [ 27,  24,  23],
#           [ 27,  24,  22],
#           ...,
#           [ 32,  28,  24],
#           [ 31,  27,  25],
#           [ 31,  27,  26]],
#
#          [[ 29,  26,  25],
#           [ 27,  25,  23],
#           [ 27,  25,  23],
#           ...,
#           [ 32,  28,  24],
#           [ 31,  27,  24],
#           [ 30,  27,  25]],
#
#          [[ 28,  26,  26],
#           [ 27,  25,  23],
#           [ 26,  25,  23],
#           ...,
#           [ 32,  28,  24],
#           [ 31,  27,  24],
#           [ 30,  27,  25]],
#
#          ...,
#
#          [[ 27,  24,  23],
#           [ 28,  25,  24],
#           [ 30,  25,  24],
#           ...,
#           [ 27,  24,  23],
#           [ 28,  24,  22],
#           [ 29,  25,  22]],
#
#          [[ 28,  23,  23],
#           [ 29,  24,  24],
#           [ 31,  25,  24],
#           ...,
#           [ 27,  24,  23],
#           [ 28,  24,  22],
#           [ 28,  24,  21]],
#
#          [[ 29,  23,  23],
#           [ 30,  24,  24],
#           [ 32,  24,  23],
#           ...,
#           [ 27,  24,  22],
#           [ 27,  23,  21],
#           [ 26,  22,  20]]],
#
#
#         [[[ 28,  24,  24],
#           [ 26,  23,  23],
#           [ 27,  24,  24],
#           ...,
#           [ 31,  28,  26],
#           [ 31,  28,  27],
#           [ 32,  28,  27]],
#
#          [[ 27,  24,  24],
#           [ 27,  24,  24],
#           [ 28,  25,  24],
#           ...,
#           [ 31,  27,  25],
#           [ 31,  27,  26],
#           [ 33,  29,  27]],
#
#          [[ 26,  24,  24],
#           [ 26,  24,  24],
#           [ 27,  24,  23],
#           ...,
#           [ 31,  26,  25],
#           [ 31,  27,  26],
#           [ 33,  29,  27]],
#
#          ...,
#
#          [[ 28,  25,  23],
#           [ 30,  27,  24],
#           [ 30,  27,  24],
#           ...,
#           [ 27,  24,  22],
#           [ 27,  24,  22],
#           [ 28,  24,  22]],
#
#          [[ 27,  24,  22],
#           [ 29,  26,  23],
#           [ 31,  26,  24],
#           ...,
#           [ 26,  23,  21],
#           [ 27,  24,  22],
#           [ 28,  25,  23]],
#
#          [[ 28,  24,  23],
#           [ 28,  24,  22],
#           [ 29,  24,  22],
#           ...,
#           [ 27,  23,  22],
#           [ 27,  24,  23],
#           [ 29,  26,  25]]],
#
#
#         [[[ 29,  25,  25],
#           [ 29,  26,  26],
#           [ 30,  27,  27],
#           ...,
#           [ 31,  27,  24],
#           [ 31,  28,  25],
#           [ 32,  29,  27]],
#
#          [[ 27,  24,  24],
#           [ 27,  25,  25],
#           [ 28,  26,  26],
#           ...,
#           [ 31,  27,  23],
#           [ 32,  28,  25],
#           [ 33,  30,  27]],
#
#          [[ 27,  24,  24],
#           [ 28,  26,  26],
#           [ 29,  27,  27],
#           ...,
#           [ 32,  28,  24],
#           [ 32,  28,  24],
#           [ 33,  29,  26]],
#
#          ...,
#
#          [[ 28,  26,  22],
#           [ 29,  26,  21],
#           [ 31,  26,  22],
#           ...,
#           [ 29,  24,  21],
#           [ 28,  23,  20],
#           [ 28,  23,  22]],
#
#          [[ 27,  26,  23],
#           [ 28,  25,  21],
#           [ 30,  25,  22],
#           ...,
#           [ 28,  23,  21],
#           [ 27,  22,  20],
#           [ 28,  24,  22]],
#
#          [[ 29,  26,  23],
#           [ 28,  24,  21],
#           [ 29,  24,  21],
#           ...,
#           [ 29,  25,  23],
#           [ 28,  24,  22],
#           [ 30,  26,  24]]],
#
#
#         ...,
#
#
#         [[[ 51,  67,  86],
#           [ 55,  59,  71],
#           [ 75,  81,  92],
#           ...,
#           [250, 248, 243],
#           [207, 212, 233],
#           [121, 116, 140]],
#
#          [[ 35,  42,  49],
#           [ 48,  47,  51],
#           [ 91,  96, 113],
#           ...,
#           [220, 224, 226],
#           [169, 177, 187],
#           [ 84,  87, 100]],
#
#          [[ 27,  26,  29],
#           [ 41,  38,  39],
#           [ 55,  64,  78],
#           ...,
#           [122, 143, 160],
#           [ 97, 104, 129],
#           [ 59,  59,  56]],
#
#          ...,
#
#          [[ 24,  23,  27],
#           [ 21,  20,  27],
#           [ 20,  19,  22],
#           ...,
#           [ 76,  79,  83],
#           [ 54,  64,  77],
#           [ 45,  51,  65]],
#
#          [[ 31,  31,  33],
#           [ 22,  23,  29],
#           [ 20,  18,  21],
#           ...,
#           [ 66,  67,  84],
#           [ 56,  65,  74],
#           [ 45,  55,  73]],
#
#          [[ 28,  28,  30],
#           [ 22,  21,  25],
#           [ 19,  18,  19],
#           ...,
#           [ 67,  63,  76],
#           [ 39,  45,  55],
#           [ 32,  37,  47]]],
#
#
#         [[[ 82,  78,  96],
#           [120, 126, 148],
#           [112, 125, 146],
#           ...,
#           [185, 182, 177],
#           [204, 210, 215],
#           [132, 114, 121]],
#
#          [[ 74,  77,  93],
#           [171, 174, 185],
#           [137, 164, 184],
#           ...,
#           [180, 181, 187],
#           [198, 200, 213],
#           [ 79,  85,  85]],
#
#          [[ 54,  50,  56],
#           [100, 106, 118],
#           [117, 132, 158],
#           ...,
#           [157, 153, 160],
#           [176, 183, 199],
#           [ 88,  80,  82]],
#
#          ...,
#
#          [[ 22,  21,  22],
#           [ 20,  19,  19],
#           [ 18,  16,  19],
#           ...,
#           [ 50,  50,  60],
#           [ 37,  43,  52],
#           [ 30,  41,  59]],
#
#          [[ 18,  16,  18],
#           [ 19,  17,  18],
#           [ 19,  18,  21],
#           ...,
#           [ 36,  44,  60],
#           [ 33,  36,  48],
#           [ 36,  43,  61]],
#
#          [[ 18,  17,  20],
#           [ 21,  20,  23],
#           [ 24,  22,  25],
#           ...,
#           [ 32,  34,  41],
#           [ 45,  42,  48],
#           [ 41,  43,  52]]],
#
#
#         [[[ 69,  79,  96],
#           [ 24,  26,  28],
#           [ 40,  42,  45],
#           ...,
#           [225, 234, 237],
#           [151, 161, 166],
#           [164, 162, 169]],
#
#          [[ 99, 110, 125],
#           [ 36,  41,  47],
#           [ 63,  56,  62],
#           ...,
#           [197, 216, 224],
#           [154, 163, 169],
#           [164, 163, 159]],
#
#          [[104, 107, 113],
#           [ 34,  37,  40],
#           [ 72,  70,  77],
#           ...,
#           [223, 237, 235],
#           [181, 192, 198],
#           [166, 167, 159]],
#
#          ...,
#
#          [[ 21,  20,  23],
#           [ 23,  24,  30],
#           [ 19,  20,  24],
#           ...,
#           [ 45,  47,  54],
#           [ 58,  62,  70],
#           [ 58,  70,  82]],
#
#          [[ 18,  17,  21],
#           [ 19,  19,  24],
#           [ 18,  18,  23],
#           ...,
#           [ 36,  36,  40],
#           [ 58,  59,  70],
#           [ 61,  69,  81]],
#
#          [[ 17,  16,  19],
#           [ 16,  15,  18],
#           [ 16,  15,  18],
#           ...,
#           [ 40,  40,  44],
#           [ 57,  62,  73],
#           [ 57,  68,  80]]]], dtype=uint8),
#  'labels': array([41, 41, 41, ..., 25, 25, 25], dtype=uint8),
#  'sizes': array([[ 26,  25],
#         [ 27,  27],
#         [ 27,  28],
#         ...,
#         [194, 169],
#         [201, 175],
#         [230, 201]], dtype=uint8)}

# %%
X_train, y_train = train['features'], train['labels']
X_test, y_test = test['features'], test['labels']
X_validation, y_validation = valid['features'], valid['labels']

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %%
X_test.shape
# Out:
# (12630, 32, 32, 3)

# %%
X_validation.shape
# Out:
# (4410, 32, 32, 3)

# %% [markdown]
# # Etapa 3: Visualização dos dados

# %%
i = 3100
plt.imshow(X_train[i])
y_train[i]
# Out:
# 1

# %%
i = 3001
plt.imshow(X_test[i])
y_test[i]
# Out:
# 1

# %%
i = 2100
plt.imshow(X_validation[i])
y_validation[i]
# Out:
# 23

# %% [markdown]
# # Etapa 4: Preparação dos dados

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
X_train_gray = np.sum(X_train / 3, axis = 3, keepdims=True)
X_test_gray = np.sum(X_test / 3, axis = 3, keepdims=True)
X_validation_gray = np.sum(X_validation / 3, axis = 3, keepdims=True)

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
X_test_gray.shape
# Out:
# (12630, 32, 32, 1)

# %%
X_validation_gray.shape
# Out:
# (4410, 32, 32, 1)

# %%
X_train_gray_norm = (X_train_gray - 128) / 128
X_test_gray_norm = (X_test_gray - 128) / 128
X_validation_gray_norm = (X_validation_gray - 128) / 128

# %%
np.max(X_train_gray_norm)
# Out:
# 0.9921875

# %%
np.min(X_train_gray_norm)
# Out:
# -0.9713541666666666

# %%
i = 60
plt.imshow(X_train_gray[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_gray_norm[i].squeeze(), cmap = 'gray')

# %%
i = 610
plt.imshow(X_test_gray[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_test[i])
plt.figure()
plt.imshow(X_test_gray_norm[i].squeeze(), cmap = 'gray')

# %%
i = 500
plt.imshow(X_validation_gray[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_validation[i])
plt.figure()
plt.imshow(X_validation_gray_norm[i].squeeze(), cmap = 'gray')

# %% [markdown]
# # Etapa 5: Criação do modelo e treinamento

# %% [markdown]
# - STEP 1: THE FIRST CONVOLUTIONAL LAYER #1
#     - Input = 32x32x1
#     - Output = 28x28x6
#     - Output = (Input-filter+1)/Stride* => (32-5+1)/1=28
#     - Used a 5x5 Filter with input depth of 3 and output depth of 6
#     - Apply a RELU Activation function to the output
#     - pooling for input, Input = 28x28x6 and Output = 14x14x6
#
# - STEP 2: THE SECOND CONVOLUTIONAL LAYER #2
#     - Input = 14x14x6
#     - Output = 10x10x16
#     - Layer 2: Convolutional layer with Output = 10x10x16
#     - Output = (Input-filter+1)/strides => 10 = 14-5+1/1
#     - Apply a RELU Activation function to the output
#     - Pooling with Input = 10x10x16 and Output = 5x5x16
#
# - STEP 3: FLATTENING THE NETWORK
#     - Flatten the network with Input = 5x5x16 and Output = 400
#
# - STEP 4: FULLY CONNECTED LAYER
#     - Layer 3: Fully Connected layer with Input = 400 and Output = 120
#     - Apply a RELU Activation function to the output
#
# - STEP 5: ANOTHER FULLY CONNECTED LAYER
#     - Layer 4: Fully Connected Layer with Input = 120 and Output = 84
#     - Apply a RELU Activation function to the output
#
# - STEP 6: FULLY CONNECTED LAYER
#     - Layer 5: Fully Connected layer with Input = 84 and Output = 43

# %%
from tensorflow.keras import layers, models

LeNet = models.Sequential()

LeNet.add(layers.Conv2D(6, (5,5), activation = 'relu', input_shape = (32, 32, 1)))
LeNet.add(layers.AveragePooling2D())

LeNet.add(layers.Conv2D(16, (5,5), activation = 'relu'))
LeNet.add(layers.AveragePooling2D())

LeNet.add(layers.Flatten())

LeNet.add(layers.Dense(120, activation='relu'))

LeNet.add(layers.Dense(84, activation='relu'))

LeNet.add(layers.Dense(43, activation='softmax'))

LeNet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 43)                3655
# =================================================================
# Total params: 64,511
# Trainable params: 64,511
# Non-trainable params: 0
# _________________________________________________________________

# %%
LeNet.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', 
              metrics = ['accuracy'])

# %%
history = LeNet.fit(X_train_gray_norm, y_train,
                    batch_size = 500,
                    epochs = 50,
                    validation_data = (X_validation_gray_norm, y_validation))
# Out:
# Train on 34799 samples, validate on 4410 samples
# Epoch 1/50
# 34799/34799 [==============================] - 1s 21us/sample - loss: 3.2622 - accuracy: 0.1449 - val_loss: 2.9195 - val_accuracy: 0.2760
# Epoch 2/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 1.8160 - accuracy: 0.5004 - val_loss: 1.5543 - val_accuracy: 0.5610
# Epoch 3/50
# 34799/34799 [==============================] - 0s 14us/sample - loss: 1.0025 - accuracy: 0.7097 - val_loss: 1.0055 - val_accuracy: 0.7247
# Epoch 4/50
# 34799/34799 [==============================] - 0s 14us/sample - loss: 0.7201 - accuracy: 0.7980 - val_loss: 0.8420 - val_accuracy: 0.7458
# Epoch 5/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.5656 - accuracy: 0.8445 - val_loss: 0.7721 - val_accuracy: 0.7787
# Epoch 6/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.4763 - accuracy: 0.8687 - val_loss: 0.7193 - val_accuracy: 0.7982
# Epoch 7/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.4159 - accuracy: 0.8859 - val_loss: 0.7308 - val_accuracy: 0.7984
# Epoch 8/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.3609 - accuracy: 0.9022 - val_loss: 0.6902 - val_accuracy: 0.8045
# Epoch 9/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.3199 - accuracy: 0.9136 - val_loss: 0.6821 - val_accuracy: 0.8159
# Epoch 10/50
# 34799/34799 [==============================] - 0s 12us/sample - loss: 0.2836 - accuracy: 0.9259 - val_loss: 0.6054 - val_accuracy: 0.8365
# Epoch 11/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.2548 - accuracy: 0.9326 - val_loss: 0.6340 - val_accuracy: 0.8422
# Epoch 12/50
# 34799/34799 [==============================] - 0s 12us/sample - loss: 0.2359 - accuracy: 0.9377 - val_loss: 0.6590 - val_accuracy: 0.8374
# Epoch 13/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.2086 - accuracy: 0.9456 - val_loss: 0.6052 - val_accuracy: 0.8533
# Epoch 14/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.1925 - accuracy: 0.9510 - val_loss: 0.6307 - val_accuracy: 0.8526
# Epoch 15/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.1766 - accuracy: 0.9545 - val_loss: 0.6754 - val_accuracy: 0.8488
# Epoch 16/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.1657 - accuracy: 0.9579 - val_loss: 0.6554 - val_accuracy: 0.8417
# Epoch 17/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.1470 - accuracy: 0.9637 - val_loss: 0.6414 - val_accuracy: 0.8494
# Epoch 18/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.1412 - accuracy: 0.9651 - val_loss: 0.6417 - val_accuracy: 0.8571
# Epoch 19/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.1303 - accuracy: 0.9675 - val_loss: 0.6761 - val_accuracy: 0.8488
# Epoch 20/50
# 34799/34799 [==============================] - 0s 14us/sample - loss: 0.1225 - accuracy: 0.9693 - val_loss: 0.6945 - val_accuracy: 0.8449
# Epoch 21/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.1106 - accuracy: 0.9729 - val_loss: 0.6856 - val_accuracy: 0.8490
# Epoch 22/50
# 34799/34799 [==============================] - 0s 12us/sample - loss: 0.1011 - accuracy: 0.9753 - val_loss: 0.7149 - val_accuracy: 0.8556
# Epoch 23/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.0958 - accuracy: 0.9766 - val_loss: 0.7079 - val_accuracy: 0.8615
# Epoch 24/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.0912 - accuracy: 0.9777 - val_loss: 0.7133 - val_accuracy: 0.8506
# Epoch 25/50
# 34799/34799 [==============================] - 0s 14us/sample - loss: 0.0842 - accuracy: 0.9801 - val_loss: 0.7310 - val_accuracy: 0.8635
# Epoch 26/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.0790 - accuracy: 0.9805 - val_loss: 0.7424 - val_accuracy: 0.8646
# Epoch 27/50
# 34799/34799 [==============================] - 0s 14us/sample - loss: 0.0777 - accuracy: 0.9798 - val_loss: 0.7683 - val_accuracy: 0.8413
# Epoch 28/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.0685 - accuracy: 0.9835 - val_loss: 0.7976 - val_accuracy: 0.8592
# Epoch 29/50
# 34799/34799 [==============================] - 0s 14us/sample - loss: 0.0665 - accuracy: 0.9826 - val_loss: 0.7187 - val_accuracy: 0.8639
# Epoch 30/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.0592 - accuracy: 0.9863 - val_loss: 0.7773 - val_accuracy: 0.8567
# Epoch 31/50
# 34799/34799 [==============================] - 0s 12us/sample - loss: 0.0529 - accuracy: 0.9881 - val_loss: 0.7730 - val_accuracy: 0.8669
# Epoch 32/50
# 34799/34799 [==============================] - 0s 14us/sample - loss: 0.0554 - accuracy: 0.9860 - val_loss: 0.7522 - val_accuracy: 0.8610
# Epoch 33/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.0513 - accuracy: 0.9871 - val_loss: 0.7892 - val_accuracy: 0.8556
# Epoch 34/50
# 34799/34799 [==============================] - 0s 14us/sample - loss: 0.0462 - accuracy: 0.9889 - val_loss: 0.7836 - val_accuracy: 0.8551
# Epoch 35/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.0453 - accuracy: 0.9891 - val_loss: 0.8365 - val_accuracy: 0.8619
# Epoch 36/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.0470 - accuracy: 0.9885 - val_loss: 0.7502 - val_accuracy: 0.8710
# Epoch 37/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.0412 - accuracy: 0.9903 - val_loss: 0.7813 - val_accuracy: 0.8633
# Epoch 38/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.0331 - accuracy: 0.9926 - val_loss: 0.8141 - val_accuracy: 0.8762
# Epoch 39/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.0319 - accuracy: 0.9926 - val_loss: 0.8214 - val_accuracy: 0.8528
# Epoch 40/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.0323 - accuracy: 0.9928 - val_loss: 0.7901 - val_accuracy: 0.8676
# Epoch 41/50
# 34799/34799 [==============================] - 0s 14us/sample - loss: 0.0320 - accuracy: 0.9921 - val_loss: 0.9166 - val_accuracy: 0.8506
# Epoch 42/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.0289 - accuracy: 0.9930 - val_loss: 0.8351 - val_accuracy: 0.8615
# Epoch 43/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.0265 - accuracy: 0.9938 - val_loss: 0.8934 - val_accuracy: 0.8592
# Epoch 44/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.0245 - accuracy: 0.9942 - val_loss: 0.8910 - val_accuracy: 0.8621
# Epoch 45/50
# 34799/34799 [==============================] - 0s 12us/sample - loss: 0.0268 - accuracy: 0.9932 - val_loss: 0.9251 - val_accuracy: 0.8590
# Epoch 46/50
# 34799/34799 [==============================] - 0s 13us/sample - loss: 0.0238 - accuracy: 0.9943 - val_loss: 0.8682 - val_accuracy: 0.8660
# Epoch 47/50
# 34799/34799 [==============================] - 0s 14us/sample - loss: 0.0225 - accuracy: 0.9944 - val_loss: 0.9795 - val_accuracy: 0.8537
# Epoch 48/50
# 34799/34799 [==============================] - 0s 14us/sample - loss: 0.0215 - accuracy: 0.9945 - val_loss: 0.8817 - val_accuracy: 0.8608
# Epoch 49/50
# 34799/34799 [==============================] - 1s 15us/sample - loss: 0.0199 - accuracy: 0.9951 - val_loss: 0.8599 - val_accuracy: 0.8649
# Epoch 50/50
# 34799/34799 [==============================] - 0s 14us/sample - loss: 0.0204 - accuracy: 0.9949 - val_loss: 0.9148 - val_accuracy: 0.8637

# %% [markdown]
# # Etapa 6: Avaliação do modelo

# %%
score = LeNet.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 12630/12630 [==============================] - 1s 81us/sample - loss: 1.1308 - accuracy: 0.8683
# Test Accuracy: 0.8682501912117004

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
val_accuracy
# Out:
# [0.27596372,
#  0.5609977,
#  0.72471654,
#  0.74580497,
#  0.7786848,
#  0.79818594,
#  0.7984127,
#  0.80453515,
#  0.815873,
#  0.8365079,
#  0.84217685,
#  0.837415,
#  0.853288,
#  0.8526077,
#  0.84875286,
#  0.8417234,
#  0.8494331,
#  0.85714287,
#  0.84875286,
#  0.844898,
#  0.8489796,
#  0.85555553,
#  0.86145127,
#  0.85056686,
#  0.8634921,
#  0.8646259,
#  0.84126985,
#  0.85918367,
#  0.8639456,
#  0.85668933,
#  0.8668934,
#  0.86099774,
#  0.85555553,
#  0.85510206,
#  0.86190474,
#  0.8709751,
#  0.86326534,
#  0.8761905,
#  0.85283446,
#  0.8675737,
#  0.85056686,
#  0.86145127,
#  0.85918367,
#  0.86213154,
#  0.85895693,
#  0.8659864,
#  0.85374147,
#  0.860771,
#  0.8648526,
#  0.8637188]

# %%
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', color = 'r', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend();

# %%
plt.plot(epochs, loss, 'ro', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend();

# %%
#predicted_classes = LeNet.predict_classes(X_test_gray_norm) -- Atualizado 17/01/22
#y_true = y_test

# %%
predict_x = LeNet.predict(X_test_gray_norm)
predicted_classes=np.argmax(predict_x,axis=1)
y_true = y_test

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (25, 25))
sns.heatmap(cm, annot = True);

# %%
L = 7
W = 7

fig, axes = plt.subplots(L, W, figsize = (12, 12))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(X_test[i])
    axes[i].set_title('Prediction = {}\n True = {}'.format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1)
